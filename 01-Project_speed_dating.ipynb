# %% [markdown]
# # Speed Dating
#
# ## Challenge description
#
# We will start a new data visualization and exploration project. Your goal will be to try to understand *love*! It's a very complicated subject so we've simplified it. Your goal is going to be to understand what happens during a speed dating and especially to understand what will influence the obtaining of a **second date**.
#
# This is a Kaggle competition on which you can find more details here :
#
# [Speed Dating Dataset](https://www.kaggle.com/annavictoria/speed-dating-experiment#Speed%20Dating%20Data%20Key.doc)
#
# Take some time to read the description of the challenge and try to understand each of the variables in the dataset. Help yourself with this from the document : *Speed Dating - Variable Description.md*
#
# ### Rendering
#
# To be successful in this project, you will need to do a descriptive analysis of the main factors that influence getting a second appointment.
#
# Over the next few days, you'll learn how to use python libraries like seaborn, plotly and bokeh to produce data visualizations that highlight relevant facts about the dataset.
#
# For today, you can start exploring the dataset with pandas to extract some statistics.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import plotly.io as pio
import plotly.express as px
import plotly.graph_objects as go

# %%
dataset = pd.read_csv("Speed Dating Data.csv", encoding='ISO-8859-1')

# %%
dataset.shape
# Out:
# (8378, 195)

# %%
pd.set_option('display.max_columns', None)
dataset.describe(include = "all")
# Out:
#                 iid           id       gender          idg       condtn  \
# count   8378.000000  8377.000000  8378.000000  8378.000000  8378.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean     283.675937     8.960248     0.500597    17.327166     1.828837
# std      158.583367     5.491329     0.500029    10.940735     0.376673
# min        1.000000     1.000000     0.000000     1.000000     1.000000
# 25%      154.000000     4.000000     0.000000     8.000000     2.000000
# 50%      281.000000     8.000000     1.000000    16.000000     2.000000
# 75%      407.000000    13.000000     1.000000    26.000000     2.000000
# max      552.000000    22.000000     1.000000    44.000000     2.000000
#
#                wave        round     position     positin1        order  \
# ...

# %%
dataset.head(12)
# Out:
#     iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0     1  1.0       0    1       1     1     10         7       NaN      4
# 1     1  1.0       0    1       1     1     10         7       NaN      3
# 2     1  1.0       0    1       1     1     10         7       NaN     10
# 3     1  1.0       0    1       1     1     10         7       NaN      5
# 4     1  1.0       0    1       1     1     10         7       NaN      7
# 5     1  1.0       0    1       1     1     10         7       NaN      6
# 6     1  1.0       0    1       1     1     10         7       NaN      1
# 7     1  1.0       0    1       1     1     10         7       NaN      2
# 8     1  1.0       0    1       1     1     10         7       NaN      8
# 9     1  1.0       0    1       1     1     10         7       NaN      9
# 10    2  2.0       0    3       1     1     10         3       NaN     10
# 11    2  2.0       0    3       1     1     10         3       NaN      9
#
# ...

# %%
pd.set_option('display.max_rows', None)
missing = 100 * dataset.isna().sum() / dataset.shape[0]
print(missing.sort_values(ascending = False))
# Out:
# num_in_3    92.026737
# numdat_3    82.143710
# expnum      78.515159
# sinc7_2     76.665075
# amb7_2      76.665075
# shar7_2     76.438291
# attr7_2     76.318931
# intel7_2    76.318931
# fun7_2      76.318931
# amb5_3      75.936978
# attr7_3     75.936978
# sinc7_3     75.936978
# intel7_3    75.936978
# fun7_3      75.936978
# amb7_3      75.936978
# shar7_3     75.936978
# shar2_3     75.936978
# attr5_3     75.936978
# sinc5_3     75.936978
# intel5_3    75.936978
# fun5_3      75.936978
# attr4_3     64.681308
# sinc4_3     64.681308
# intel4_3    64.681308
# fun4_3      64.681308
# amb4_3      64.681308
# shar4_3     64.681308
# attr2_3     64.681308
# sinc2_3     64.681308
# fun2_3      64.681308
# intel2_3    64.681308
# amb2_3      64.681308
# mn_sat      62.604440
# tuition     57.233230
# you_call    52.566245
# shar1_3     52.566245
# date_3      52.566245
# attr1_3     52.566245
# sinc1_3     52.566245
# intel1_3    52.566245
# fun1_3      52.566245
# ...

# %% [markdown]
# Description of participants

# %%
# gender : Female = 0 , Male = 1
dataset['gender'] = dataset['gender'].map({ 0 : "Female", 1 : "Male"})
# race of partner :
#   Black/African American=1
#	European/Caucasian-American=2
#	Latino/Hispanic American=3
#	Asian/Pacific Islander/Asian-American=4
#	Native American=5
#	Other=6
dataset['race'] = dataset['race'].map({ 1 : "Black/African",
                                        2 : "European/Caucasian",
                                        3 : "Latino/Hispanic",
                                        4 : "Asian/Pacific Islander/Asian",
                                        5 : "Native",
                                        6 : "Other"})

# %%
print('number of participants : ', len(dataset['iid'].unique()))
print('number of waves : ', len(dataset['wave'].unique()))
# Out:
# number of participants :  551
# number of waves :  21

# %%
pd.set_option('display.max_rows',10)
df_ind = dataset.groupby('iid')['gender', 'age', 'race', 'wave',
                        'attr1_1','sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1',
                        'attr4_1','sinc4_1', 'intel4_1', 'fun4_1', 'amb4_1', 'shar4_1',
                        'attr2_1','sinc2_1', 'intel2_1', 'fun2_1', 'amb2_1', 'shar2_1' ].head(1).reset_index(drop=True)
# Out:
# C:\Users\sylva\AppData\Local\Temp\ipykernel_18944\400446263.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_ind = dataset.groupby('iid')['gender', 'age', 'race', 'wave',

# %%
df_ind
# Out:
#      gender   age                          race  wave  attr1_1  sinc1_1  \
# 0    Female  21.0  Asian/Pacific Islander/Asian     1     15.0     20.0
# 1    Female  24.0            European/Caucasian     1     45.0      5.0
# 2    Female  25.0            European/Caucasian     1     35.0     10.0
# 3    Female  23.0            European/Caucasian     1     20.0     20.0
# 4    Female  21.0            European/Caucasian     1     20.0      5.0
# ..      ...   ...                           ...   ...      ...      ...
# 546    Male  30.0            European/Caucasian    21     40.0     10.0
# 547    Male  28.0            European/Caucasian    21     20.0     20.0
# 548    Male  30.0            European/Caucasian    21     30.0      3.0
# 549    Male  27.0                 Black/African    21     40.0     20.0
# 550    Male  25.0            European/Caucasian    21     70.0      0.0
#
#      intel1_1  fun1_1  amb1_1  shar1_1  attr4_1  sinc4_1  intel4_1  fun4_1  \
# ...

# %%
sns.set(rc = {'figure.figsize':(15,8)})

print(df_ind['gender'].value_counts())
sns.countplot(data = df_ind , x ='gender').set(title = "the frequency table of gender")
# Out:
# Male      277
# Female    274
# Name: gender, dtype: int64
# [Text(0.5, 1.0, 'the frequency table of gender')]

# %%
# Distribution of age
print(df_ind['age'].describe())

fig, axs = plt.subplots(ncols=2)
sns.histplot(data = df_ind , x = 'age', kde=True, bins= 20, ax = axs[0])
sns.boxplot(data = df_ind , x = 'age', ax = axs[1])

# Adding titles to subplots
axs[0].set_title('Distribution of age')
axs[1].set_title('boxplot for age')
# Out:
# count    543.000000
# mean      26.359116
# std        3.766960
# min       18.000000
# 25%       24.000000
# 50%       26.000000
# 75%       28.000000
# max       55.000000
# Name: age, dtype: float64
# Text(0.5, 1.0, 'boxplot for age')

# %%
sns.countplot(data = df_ind, x = 'race').set(title = "the frequency table of the different race")
# Out:
# [Text(0.5, 1.0, 'the frequency table of the different race')]

# %%
sns.countplot(data = df_ind, x = 'wave').set(title = 'the participant number by wave')
# Out:
# [Text(0.5, 1.0, 'the subject number by wave')]

# %% [markdown]
# Statistics before the event

# %%
look = df_ind.groupby(['gender'])[['attr1_1','sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1']].mean().reset_index()
look
# Out:
#    gender    attr1_1   sinc1_1   intel1_1     fun1_1     amb1_1    shar1_1
# 0  Female  18.020372  18.22223  20.971004  17.299108  12.818476  12.697836
# 1    Male  27.248800  16.37960  19.387418  17.600839   8.823956  10.982271

# %%
data = pd.pivot_table(look, values = ['attr1_1','sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1'], columns = 'gender')
data
# Out:
# gender       Female       Male
# amb1_1    12.818476   8.823956
# attr1_1   18.020372  27.248800
# fun1_1    17.299108  17.600839
# intel1_1  20.971004  19.387418
# shar1_1   12.697836  10.982271
# sinc1_1   18.222230  16.379600

# %%
# look for in the opposite sex
labels = ['Ambitious','Attractive', 'Fun', 'Intelligent','Shared interests','Sincere']
plt.figure(figsize=(18,18))
plt.subplot(221)
plt.pie(data['Female'] ,labels = labels, explode = (0, 0, 0, 0.1 ,0, 0), autopct='%1.1f%%')
plt.title(" look Female for in the opposite sex")
# look for in the opposite sex
plt.subplot(222)
plt.pie(data['Male'] ,labels = labels, explode = (0, 0.1, 0, 0,0, 0), autopct='%1.1f%%')
plt.title(" look Male for in the opposite sex")
plt.show()

# %% [markdown]
# * Male : looks especially for the attribute : attractive
# * Female : it is balanced between the following attributes : Intelligent, Sincere, Attractive, Fun
# * Attributes Shared interests and Ambitious sont les moins souhaitable for Female et Male

# %%
# we want to know what you think MOST of your fellow men/women look for in the opposite sex.
look_o = df_ind.groupby(['gender'])[['attr4_1','sinc4_1', 'intel4_1', 'fun4_1', 'amb4_1', 'shar4_1']].mean().reset_index()
data_o = pd.pivot_table(look_o, values = ['attr4_1','sinc4_1', 'intel4_1', 'fun4_1', 'amb4_1', 'shar4_1'], columns = 'gender')

labels = ['Ambitious','Attractive', 'Fun', 'Intelligent','Shared interests','Sincere']
plt.figure(figsize=(18,18))
plt.subplot(221)
plt.pie(data_o['Female'] ,labels = labels, explode = (0, 0.1, 0, 0 ,0, 0), autopct='%1.1f%%')
plt.title("Female think that Male looks :")
# look for in the opposite sex
plt.subplot(222)
plt.pie(data_o['Male'] ,labels = labels, explode = (0, 0.1, 0, 0,0, 0), autopct='%1.1f%%')
plt.title("Male think that Female looks :")
plt.show()

# %% [markdown]
# Men/women think most of your fellow look for in the attribute Attractive

# %%
# What do you think the opposite sex looks for in a date
look_o_date = df_ind.groupby(['gender'])[['attr2_1','sinc2_1', 'intel2_1', 'fun2_1', 'amb2_1', 'shar2_1']].mean().reset_index()
data_o_date = pd.pivot_table(look_o_date, values = ['attr2_1','sinc2_1', 'intel2_1', 'fun2_1', 'amb2_1', 'shar2_1'], columns = 'gender')

labels = ['Ambitious','Attractive', 'Fun', 'Intelligent','Shared interests','Sincere']
plt.figure(figsize=(18,18))
plt.subplot(221)
plt.pie(data_o_date['Female'] ,labels = labels, explode = (0, 0.1, 0, 0 ,0, 0), autopct='%1.1f%%')
plt.title("Female think that Male looks for in a date :")
# look for in the opposite sex
plt.subplot(222)
plt.pie(data_o_date['Male'] ,labels = labels, explode = (0, 0.1, 0, 0,0, 0), autopct='%1.1f%%')
plt.title("Male think that Female looks for in a date :")
plt.show()

# %% [markdown]
# Match

# %%
list_activities = ['sports', 'tvsports', 'exercise', 'dining', 'museums','art', 'hiking',
	'gaming', 'clubbing', 'reading', 'tv','theater', 'movies', 'concerts', 'music', 'shopping', 'yoga']
df_activities = dataset.groupby('iid')[list_activities].mean().reset_index()
df_activities
# Out:
#      iid  sports  tvsports  exercise  dining  museums   art  hiking  gaming  \
# 0      1     9.0       2.0       8.0     9.0      1.0   1.0     5.0     1.0
# 1      2     3.0       2.0       7.0    10.0      8.0   6.0     3.0     5.0
# 2      3     3.0       8.0       7.0     8.0      5.0   5.0     8.0     4.0
# 3      4     1.0       1.0       6.0     7.0      6.0   7.0     7.0     5.0
# 4      5     7.0       4.0       7.0     7.0      6.0   8.0     6.0     6.0
# ..   ...     ...       ...       ...     ...      ...   ...     ...     ...
# 546  548    10.0       8.0       4.0    10.0      3.0   2.0     2.0     5.0
# 547  549     8.0       5.0       6.0     9.0      7.0   7.0     4.0     8.0
# 548  550     5.0       3.0       5.0     9.0      7.0   8.0     3.0     3.0
# 549  551     6.0       1.0       7.0     6.0      7.0   3.0     2.0     1.0
# 550  552     8.0       2.0       5.0    10.0     10.0  10.0     7.0     1.0
#
# ...

# %%
# match : 1 = yes, 0 = no
# target ?
print(dataset['match'].value_counts()/dataset['match'].shape[0])
sns.countplot(data = dataset, x ='match')
# Out:
# 0    0.835283
# 1    0.164717
# Name: match, dtype: float64
# <AxesSubplot:xlabel='match', ylabel='count'>

# %%
# 1= yes, 0=no
print(dataset['samerace'].value_counts()/dataset['samerace'].shape[0])
sns.countplot(data = dataset, x ='samerace')
# Out:
# 0    0.604201
# 1    0.395799
# Name: samerace, dtype: float64
# <AxesSubplot:xlabel='samerace', ylabel='count'>

# %%
# correlation between participant’s and partner’s ratings of interests in Time 1
print(dataset['int_corr'].describe())
sns.displot(data = dataset , x = 'int_corr', kde=True)
# Out:
# count    8220.000000
# mean        0.196010
# std         0.303539
# min        -0.830000
# 25%        -0.020000
# 50%         0.210000
# 75%         0.430000
# max         0.910000
# Name: int_corr, dtype: float64

# %%
sns.catplot(x="match", y="int_corr", kind='box', data=dataset)

# %%
print(dataset['pf_o_att'].describe())
sns.displot(data = dataset , x = 'pf_o_att', kde=True, bins = 20)
# Out:
# count    8289.000000
# mean       22.495347
# std        12.569802
# min         0.000000
# 25%        15.000000
# 50%        20.000000
# 75%        25.000000
# max       100.000000
# Name: pf_o_att, dtype: float64

# %%
# partner’s stated preference at Time 1 for all 6 attributes
preference = dataset[['pf_o_att', 'pf_o_sin','pf_o_int','pf_o_fun', 'pf_o_amb', 'pf_o_sha']].mean()
labels = ['Attractive', 'Sincere', 'Intelligent', 'Fun', 'Ambitious', 'Shared interests']
plt.figure(figsize=(8,8))
plt.pie(preference ,labels = labels, autopct='%1.1f%%')
plt.title("partner’s stated preference")
plt.show()

# %%
# partner’s stated preference at Time 1 for all 6 attributes
look2 = dataset[['attr7_2', 'sinc7_2', 'intel7_2', 'fun7_2', 'amb7_2', 'shar7_2']].mean()
labels = ['Attractive', 'Sincere', 'Intelligent', 'Fun', 'Ambitious', 'Shared interests']
plt.figure(figsize=(8,8))
plt.pie(look2 ,labels = labels, autopct='%1.1f%%')
plt.title(" best reflects the actual importance of these attributes in your decisions")
plt.show()

# %%
list_rating = ['attr_o','sinc_o','intel_o','fun_o','amb_o','shar_o']
rating = dataset.groupby('dec_o')[list_rating].mean().reset_index()
rating
# Out:
#    dec_o    attr_o    sinc_o   intel_o     fun_o     amb_o    shar_o
# 0      0  5.367224  6.858257  7.077483  5.697835  6.494758  4.719604
# 1      1  7.285645  7.595916  7.756122  7.332995  7.159272  6.462085

# %%
data = pd.pivot_table(rating, values = ['attr_o','sinc_o','intel_o','fun_o','amb_o','shar_o'], columns = 'dec_o')
data
# Out:
# dec_o           0         1
# amb_o    6.494758  7.159272
# attr_o   5.367224  7.285645
# fun_o    5.697835  7.332995
# intel_o  7.077483  7.756122
# shar_o   4.719604  6.462085
# sinc_o   6.858257  7.595916

# %%
# rating by partner the night of the event, for all 6 attributes
labels = [ 'Attractive', 'Sincere', 'Intelligent', 'Fun', 'Ambitious', 'Shared interests']
plt.figure(figsize=(12,12))

plt.subplot(221)
plt.bar(height = data.iloc[:,0], x = labels )
plt.title("rating by partner the night of the event, for all 6 attributes")
plt.xlabel("decision of partner : No")
plt.subplot(222)
plt.bar(height = data.iloc[:,1], x = labels, color ='orange' )
plt.title("rating by partner the night of the event, for all 6 attributes")
plt.xlabel("decision of partner : Yes")
plt.show()

# %%
print(dataset['dec_o'].value_counts())
sns.countplot(data = dataset, x ='dec_o')
# Out:
# 0    4863
# 1    3515
# Name: dec_o, dtype: int64
# <AxesSubplot:xlabel='dec_o', ylabel='count'>

# %%
df_corr = dataset[['match', 'pf_o_att', 'pf_o_sin','pf_o_int','pf_o_fun', 'pf_o_amb', 'pf_o_sha']].corr()
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(df_corr, annot=True, ax=ax)
plt.title("correlation between match and partner’s stated preference ")
# Out:
# Text(0.5, 1.0, 'correlation between match and partner’s stated preference ')

# %%
df_corr = dataset[['dec_o', 'pf_o_att', 'pf_o_sin','pf_o_int','pf_o_fun', 'pf_o_amb', 'pf_o_sha']].corr()
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(df_corr, annot=True, ax=ax)
plt.title("correlation between decision of partner and partner’s stated preference")
# Out:
# Text(0.5, 1.0, 'correlation between decision of partner and partner’s stated preference')

# %%
df_corr = dataset[['dec_o', 'attr_o','sinc_o','intel_o','fun_o','amb_o','shar_o']].corr()
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(df_corr, annot=True, ax=ax)
plt.title("correlation between decision of partner and rating by partner")
# Out:
# Text(0.5, 1.0, 'correlation between decision of partner and rating by partner')

# %%
df_corr2 = dataset[['match', 'attr_o','sinc_o','intel_o','fun_o','amb_o','shar_o']].corr()
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(df_corr2, annot=True, ax=ax)
plt.title("correlation between match and rating by partner")
# Out:
# Text(0.5, 1.0, 'correlation between match and rating by partner')

# %%
list_activities = ['sports', 'tvsports', 'exercise', 'dining', 'museums','art', 'hiking',
	'gaming', 'clubbing', 'reading', 'tv','theater', 'movies', 'concerts', 'music', 'shopping', 'yoga']
df_activities = dataset.groupby('match')[list_activities].mean().reset_index()
df_activities
# Out:
#    match    sports  tvsports  exercise    dining   museums       art  \
# 0      0  6.400058  4.581050  6.235650  7.757427  6.972166  6.682867
# 1      1  6.553114  4.547253  6.297436  7.917949  7.054945  6.875458
#
#      hiking    gaming  clubbing   reading        tv   theater    movies  \
# 0  5.709547  3.865446  5.684453  7.660513  5.320450  6.776031  7.936977
# 1  5.876923  3.961172  6.058608  7.769963  5.221245  6.776557  7.831502
#
#    concerts     music  shopping      yoga
# 0  6.799539  7.832708  5.632824  4.295068
# 1  6.956777  7.944322  5.623443  4.563370

# %%
data = pd.pivot_table(df_activities, values = list_activities, columns = 'match')
data
# Out:
# match            0         1
# art       6.682867  6.875458
# clubbing  5.684453  6.058608
# concerts  6.799539  6.956777
# dining    7.757427  7.917949
# exercise  6.235650  6.297436
# gaming    3.865446  3.961172
# hiking    5.709547  5.876923
# movies    7.936977  7.831502
# museums   6.972166  7.054945
# music     7.832708  7.944322
# reading   7.660513  7.769963
# shopping  5.632824  5.623443
# sports    6.400058  6.553114
# theater   6.776031  6.776557
# tv        5.320450  5.221245
# tvsports  4.581050  4.547253
# yoga      4.295068  4.563370

# %%
#  How interested are you in the following activities, on a scale of 1-10?
labels = list_activities

plt.figure(figsize=(12,12))

plt.subplot(221)
plt.bar(height = data.iloc[:,0], x = labels )
plt.title("the following activities, on a scale of 1-10, match : no")
plt.xlabel("decision of partner : No")
plt.subplot(222)
plt.bar(height = data.iloc[:,1], x = labels, color ='orange' )
plt.title("the following activities, on a scale of 1-10, match : yes")
plt.xlabel("decision of partner : Yes")
plt.show()

# %%
df_corr = dataset.corr()

# %%
df_corr['match'].abs().sort_values(ascending=False)
# Out:
# match       1.000000
# dec_o       0.522326
# dec         0.521943
# like_o      0.305853
# like        0.305723
# fun_o       0.277700
# fun         0.277545
# shar_o      0.270840
# shar        0.270679
# attr_o      0.260837
# attr        0.260676
# prob_o      0.255574
# prob        0.255531
# them_cal    0.202762
# intel       0.169532
# intel_o     0.169448
# sinc_o      0.164523
# sinc        0.164449
# num_in_3    0.156042
# expnum      0.143755
# amb         0.140042
# amb_o       0.139927
# match_es    0.130592
# date_3      0.127916
# numdat_3    0.114468
# met_o       0.106569
# you_call    0.083922
# shar2_3     0.077851
# fun7_2      0.073412
# date        0.063610
# go_out      0.060526
# fun3_2      0.060186
# shar7_2     0.060104
# satis_2     0.059370
# sinc4_1     0.058424
# fun1_2      0.058183
# intel2_3    0.057655
# clubbing    0.055435
# sinc4_2     0.053498
# fun3_1      0.051066
# intel2_2    0.050187
# imprace     0.049032
# fun1_3      0.048441
# ...
