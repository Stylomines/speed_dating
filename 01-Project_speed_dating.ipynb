# %% [markdown]
# # Speed Dating
#
# ## Challenge description
#
# We will start a new data visualization and exploration project. Your goal will be to try to understand *love*! It's a very complicated subject so we've simplified it. Your goal is going to be to understand what happens during a speed dating and especially to understand what will influence the obtaining of a **second date**.
#
# This is a Kaggle competition on which you can find more details here :
#
# [Speed Dating Dataset](https://www.kaggle.com/annavictoria/speed-dating-experiment#Speed%20Dating%20Data%20Key.doc)
#
# Take some time to read the description of the challenge and try to understand each of the variables in the dataset. Help yourself with this from the document : *Speed Dating - Variable Description.md*
#
# ### Rendering
#
# To be successful in this project, you will need to do a descriptive analysis of the main factors that influence getting a second appointment.
#
# Over the next few days, you'll learn how to use python libraries like seaborn, plotly and bokeh to produce data visualizations that highlight relevant facts about the dataset.
#
# For today, you can start exploring the dataset with pandas to extract some statistics.

# %%
import pandas as pd

# %%
dataset = pd.read_csv("Speed Dating Data.csv", encoding='ISO-8859-1')
dataset.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4  ...
# 1    1  1.0       0    1       1     1     10         7       NaN      3  ...
# 2    1  1.0       0    1       1     1     10         7       NaN     10  ...
# 3    1  1.0       0    1       1     1     10         7       NaN      5  ...
# 4    1  1.0       0    1       1     1     10         7       NaN      7  ...
#
#    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  intel5_3  \
# 0      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 1      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 2      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 3      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 4      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
#
#    fun5_3  amb5_3
# 0     NaN     NaN
# ...

# %%
dataset.shape
# Out:
# (8378, 195)

# %%
pd.set_option('display.max_columns', None)
dataset.describe(include = "all")
# Out:
#                 iid           id       gender          idg       condtn  \
# count   8378.000000  8377.000000  8378.000000  8378.000000  8378.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean     283.675937     8.960248     0.500597    17.327166     1.828837
# std      158.583367     5.491329     0.500029    10.940735     0.376673
# min        1.000000     1.000000     0.000000     1.000000     1.000000
# 25%      154.000000     4.000000     0.000000     8.000000     2.000000
# 50%      281.000000     8.000000     1.000000    16.000000     2.000000
# 75%      407.000000    13.000000     1.000000    26.000000     2.000000
# max      552.000000    22.000000     1.000000    44.000000     2.000000
#
#                wave        round     position     positin1        order  \
# ...

# %%
pd.set_option('display.max_columns', None)
dataset.head(12)
# Out:
#     iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0     1  1.0       0    1       1     1     10         7       NaN      4
# 1     1  1.0       0    1       1     1     10         7       NaN      3
# 2     1  1.0       0    1       1     1     10         7       NaN     10
# 3     1  1.0       0    1       1     1     10         7       NaN      5
# 4     1  1.0       0    1       1     1     10         7       NaN      7
# 5     1  1.0       0    1       1     1     10         7       NaN      6
# 6     1  1.0       0    1       1     1     10         7       NaN      1
# 7     1  1.0       0    1       1     1     10         7       NaN      2
# 8     1  1.0       0    1       1     1     10         7       NaN      8
# 9     1  1.0       0    1       1     1     10         7       NaN      9
# 10    2  2.0       0    3       1     1     10         3       NaN     10
# 11    2  2.0       0    3       1     1     10         3       NaN      9
#
# ...

# %%
pd.set_option('display.max_rows', None)
missing = 100 * dataset.isna().sum() / dataset.shape[0]
print(missing.sort_values(ascending = False))
# Out:
# num_in_3    92.026737
# numdat_3    82.143710
# expnum      78.515159
# sinc7_2     76.665075
# amb7_2      76.665075
# shar7_2     76.438291
# attr7_2     76.318931
# intel7_2    76.318931
# fun7_2      76.318931
# amb5_3      75.936978
# attr7_3     75.936978
# sinc7_3     75.936978
# intel7_3    75.936978
# fun7_3      75.936978
# amb7_3      75.936978
# shar7_3     75.936978
# shar2_3     75.936978
# attr5_3     75.936978
# sinc5_3     75.936978
# intel5_3    75.936978
# fun5_3      75.936978
# attr4_3     64.681308
# sinc4_3     64.681308
# intel4_3    64.681308
# fun4_3      64.681308
# amb4_3      64.681308
# shar4_3     64.681308
# attr2_3     64.681308
# sinc2_3     64.681308
# fun2_3      64.681308
# intel2_3    64.681308
# amb2_3      64.681308
# mn_sat      62.604440
# tuition     57.233230
# you_call    52.566245
# shar1_3     52.566245
# date_3      52.566245
# attr1_3     52.566245
# sinc1_3     52.566245
# intel1_3    52.566245
# fun1_3      52.566245
# ...

# %% [markdown]
# # Speed Dating Data Key Statistics

# %%
import seaborn as sns

# %%
dataset['gender'].value_counts()
# Out:
# 1    4194
# 0    4184
# Name: gender, dtype: int64

# %%
# gender : Female = 0 , Male = 1
sns.countplot(data = dataset, x ='gender', label= )
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
dataset['condtn'].value_counts()
# Out:
# 2    6944
# 1    1434
# Name: condtn, dtype: int64

# %%
# 1=limited choice , 2=extensive choice
sns.countplot(data = dataset, x ='condtn')
# Out:
# <AxesSubplot:xlabel='condtn', ylabel='count'>

# %%
dataset['wave'].value_counts()
# Out:
# 21    968
# 11    882
# 9     800
# 14    720
# 15    684
# 4     648
# 2     608
# 7     512
# 19    450
# 12    392
# 17    280
# 3     200
# 8     200
# 1     200
# 5     190
# 13    180
# 10    162
# 16     96
# 20     84
# 18     72
# 6      50
# Name: wave, dtype: int64

# %%
sns.countplot(data = dataset, x = 'wave')
# Out:
# <AxesSubplot:xlabel='wave', ylabel='count'>

# %%
dataset['round'].value_counts()
# Out:
# 18    1350
# 20    1160
# 22     968
# 21     882
# 10     880
# 16     816
# 19     646
# 14     532
# 15     450
# 9      252
# 6      162
# 11     140
# 5       50
# 8       48
# 7       42
# Name: round, dtype: int64

# %%
dataset['match'].value_counts()/dataset['match'].shape[0]
# Out:
# 0    0.835283
# 1    0.164717
# Name: match, dtype: float64

# %%
# match : 1 = yes, 0 = no
# target ?
sns.countplot(data = dataset, x ='match')
# Out:
# <AxesSubplot:xlabel='match', ylabel='count'>

# %%
dataset['samerace'].value_counts()/dataset['samerace'].shape[0]
# Out:
# 0    0.604201
# 1    0.395799
# Name: samerace, dtype: float64

# %%
# 1= yes, 0=no
sns.countplot(data = dataset, x ='samerace')
# Out:
# <AxesSubplot:xlabel='samerace', ylabel='count'>

# %%
import matplotlib.pyplot as plt

# %%
print(dataset['int_corr'].describe())
sns.displot(data = dataset , x = 'int_corr', kde=True)
# Out:
# count    8220.000000
# mean        0.196010
# std         0.303539
# min        -0.830000
# 25%        -0.020000
# 50%         0.210000
# 75%         0.430000
# max         0.910000
# Name: int_corr, dtype: float64

# %%
print(dataset['age_o'].describe())
# Distribution of age
sns.displot(data = dataset , x = 'age_o', kde=True, bins= 20)
# Out:
# count    8274.000000
# mean       26.364999
# std         3.563648
# min        18.000000
# 25%        24.000000
# 50%        26.000000
# 75%        28.000000
# max        55.000000
# Name: age_o, dtype: float64

# %%
sns.boxplot(data = dataset , x = 'age_o')
# Out:
# <AxesSubplot:xlabel='age_o'>

# %%
print(dataset['race_o'].value_counts())

# race of partner :
#   Black/African American=1
#	European/Caucasian-American=2
#	Latino/Hispanic American=3
#	Asian/Pacific Islander/Asian-American=4
#	Native American=5
#	Other=6
sns.countplot(data = dataset, x ='race_o')
# Out:
# 2.0    4722
# 4.0    1978
# 3.0     664
# 6.0     521
# 1.0     420
# Name: race_o, dtype: int64
# <AxesSubplot:xlabel='race_o', ylabel='count'>

# %%
print(dataset['pf_o_att'].describe())
sns.displot(data = dataset , x = 'pf_o_att', kde=True, bins = 20)
# Out:
# count    8289.000000
# mean       22.495347
# std        12.569802
# min         0.000000
# 25%        15.000000
# 50%        20.000000
# 75%        25.000000
# max       100.000000
# Name: pf_o_att, dtype: float64

# %%
preference = dataset[['pf_o_att', 'pf_o_sin','pf_o_int','pf_o_fun',	'pf_o_amb',	'pf_o_sha']].mean()

plt.figure(figsize=(10,10))
plt.pie(preference ,labels = preference.index, autopct='%1.1f%%')
plt.title("partner’s stated preference")
plt.show()

# %%
dataset['dec_o'].value_counts()
# Out:
# 0    4863
# 1    3515
# Name: dec_o, dtype: int64

# %%
dataset['attr_o'].describe()
# Out:
# count    8166.000000
# mean        6.190411
# std         1.950305
# min         0.000000
# 25%         5.000000
# 50%         6.000000
# 75%         8.000000
# max        10.500000
# Name: attr_o, dtype: float64

# %%
df_corr = dataset.corr()
df_corr
# Out:
# 0.625

# %%
pd.set_option('display.max_rows', None)
df_corr['date_3'].sort_values(ascending = False)
